# %%
import pandas as pd
import numpy  as np

import pickle 

from pathlib import Path

import time


import sys
sys.path.append("D:/analyze_Pearson_residuals")

from  nru_DE import *


pd.set_option('display.max_columns', 5)

# %%
np.random.seed( 12345 )

# %%
#### user specified
data_folder = r"D:/analyze_Pearson_residuals/"

data_subfolder = "33k_PBMC"

data_path = Path ( data_folder + data_subfolder )

# %%
# output data
nru_dict_pkl =  "nru_dict.pkl"
DE_stats_pkl = "DE_stats.pkl"

counts_scipy_csc_pkl  = "counts_scipy_csc.pkl"
gene_array_pkl  = "gene_array.pkl"
cell_array_pkl  = "cell_array.pkl"


# input data
counts_pkl = "counts_sparse.pkl" # sparse pandas data frame: cells in columns; genes in rows
clusters_pkl = "clusters.pkl"


 
# paths: output data
nru_dict_dsn = data_path / nru_dict_pkl
DE_stats_dsn = data_path / DE_stats_pkl

counts_scipy_csc_dsn = data_path / counts_scipy_csc_pkl
gene_array_dsn = data_path / gene_array_pkl 
cell_array_dsn = data_path / cell_array_pkl  



# paths: input data
counts_dsn = data_path / counts_pkl
clusters_dsn = data_path / clusters_pkl

# %%
pctl_list = [.01,.05, .10, .25, .5, .75, .90, .95, .99 ]

# %%
df_clusters = pd.read_pickle ( clusters_dsn )	
print ( ' df_clusters'  )
print ( '\n', df_clusters )

print ( '\n\n df_clusters.value_counts' )
print ( df_clusters['Cluster'].value_counts() )
# Out:
#  df_clusters
#
#                    Cluster
# Barcode
# AAACATTGACGACT-1        1
# AAACATTGACGGGA-1        8
# AAACATTGCCGCTT-1        2
# AAACATTGCTCATT-1        3
# AAACCGTGCCCTCA-1        5
# ...                   ...
# TTTGCATGCACTAG-6        3
# TTTGCATGCCGAAT-6        1
# TTTGCATGGAGGTG-6        7
# TTTGCATGGATAAG-6        3
# TTTGCATGGGCATT-6        4
#
# [33148 rows x 1 columns]
#
#
#  df_clusters.value_counts
# 1     7406
# 4     7047
# 2     6307
# 5     4164
# 3     3660
# 7     2288
# 8     1959
# 6      135
# 10     107
# 9       75
# Name: Cluster, dtype: int64

# %%
df_counts_sparse = pd.read_pickle ( counts_dsn )
print ( ' df_counts_sparse:' )
print ( df_counts_sparse )
print ( '\n type( df_counts_sparse ) ', type ( df_counts_sparse ))
print ( '\n df_counts_sparse.sparse.density: ', df_counts_sparse.sparse.density)
# Out:
#  df_counts_sparse:
#                  AAACATTGACGACT-1  AAACATTGACGGGA-1  ...  TTTGCATGGATAAG-6  \
# ENSEMBL_ID                                           ...
# ENSG00000239945                 0                 0  ...                 0
# ENSG00000237683                 0                 0  ...                 0
# ENSG00000228463                 0                 0  ...                 0
# ENSG00000235373                 0                 0  ...                 0
# ENSG00000228327                 0                 0  ...                 0
# ...                           ...               ...  ...               ...
# ENSG00000212884                 0                 0  ...                 0
# ENSG00000215615                 0                 0  ...                 0
# ENSG00000215764                 0                 0  ...                 0
# ENSG00000215700                 1                 0  ...                 1
# ENSG00000215699                 0                 0  ...                 0
#
#                  TTTGCATGGGCATT-6
# ENSEMBL_ID
# ENSG00000239945                 0
# ENSG00000237683                 0
# ENSG00000228463                 0
# ENSG00000235373                 0
# ENSG00000228327                 0
# ...                           ...
# ENSG00000212884                 0
# ENSG00000215615                 0
# ENSG00000215764                 0
# ENSG00000215700                 0
# ENSG00000215699                 0
#
# [20678 rows x 33148 columns]
#
#  type( df_counts_sparse )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse.sparse.density:  0.0370311047618005

# %%
start_time = time.time()
nru_dict = nru ( df_counts_sparse ) 
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru elapsed time: ',  f"{ elapsed:.1f}", ' seconds'  )
# Out:
# counts_sparse_selected_genes.shape:  (12324, 33148)
# counts_sparse_selected_csr.shape:  (12324, 33148)
# calculating sum of squares of Pearson residuals using all cells
# calculating sum of squares of Pearson residuals using cell sample  0
# calculating sum of squares of Pearson residuals using cell sample  1
# calculating sum of squares of Pearson residuals using cell sample  2
# calculating sum of squares of Pearson residuals using cell sample  3
# calculating sum of squares of Pearson residuals using cell sample  4
# calculating sum of squares of Pearson residuals using cell sample  5
# calculating sum of squares of Pearson residuals using cell sample  6
# calculating sum of squares of Pearson residuals using cell sample  7
# calculating sum of squares of Pearson residuals using cell sample  8
# calculating sum of squares of Pearson residuals using cell sample  9
# calculating sum of squares of Pearson residuals using cell sample  10
# calculating sum of squares of Pearson residuals using cell sample  11
# calculating sum of squares of Pearson residuals using cell sample  12
# calculating sum of squares of Pearson residuals using cell sample  13
# calculating sum of squares of Pearson residuals using cell sample  14
# calculating sum of squares of Pearson residuals using cell sample  15
# calculating sum of squares of Pearson residuals using cell sample  16
# calculating sum of squares of Pearson residuals using cell sample  17
# calculating sum of squares of Pearson residuals using cell sample  18
# calculating sum of squares of Pearson residuals using cell sample  19
# calculating sum of squares of Pearson residuals using cell sample  20
# calculating sum of squares of Pearson residuals using cell sample  21
# calculating sum of squares of Pearson residuals using cell sample  22
# calculating sum of squares of Pearson residuals using cell sample  23
# calculating sum of squares of Pearson residuals using cell sample  24
# calculating sum of squares of Pearson residuals using cell sample  25
# calculating sum of squares of Pearson residuals using cell sample  26
# calculating sum of squares of Pearson residuals using cell sample  27
# calculating sum of squares of Pearson residuals using cell sample  28
# calculating sum of squares of Pearson residuals using cell sample  29
# calculating sum of squares of Pearson residuals using cell sample  30
# calculating sum of squares of Pearson residuals using cell sample  31
# calculating sum of squares of Pearson residuals using cell sample  32
# calculating sum of squares of Pearson residuals using cell sample  33
# calculating sum of squares of Pearson residuals using cell sample  34
# calculating sum of squares of Pearson residuals using cell sample  35
# calculating sum of squares of Pearson residuals using cell sample  36
# calculating sum of squares of Pearson residuals using cell sample  37
# calculating sum of squares of Pearson residuals using cell sample  38
# calculating sum of squares of Pearson residuals using cell sample  39
# function nru elapsed time:  116.2  seconds

# %%
df_gene_stats = nru_dict['df_gene_stats']
df_gene_stats.sort_values ( ['A_g'], ascending=False, inplace=True )
df_selected_cells = nru_dict['df_selected_cells']
df_residuals = nru_dict['df_residuals']

pd.set_option('display.max_columns', 8)
print ( '\n df_gene_stats'  )
print ( df_gene_stats  )
pd.set_option('display.max_columns', 5)

print ( '\n\n df_gene_stats.describe' )
print ( df_gene_stats[['M_g', 'A_g']].describe ( percentiles=pctl_list ) )

print ( '\n\n df_selected_cells'  )
print ( df_selected_cells ) 

print ( '\n\n df_residuals'  )
print ( df_residuals  )
# Out:
#  df_gene_stats
#                   count  nz_cells         M_g         A_g  ...          36  \
# ENSG00000254709   32897      1679  594.080034  321.476696  ...  696.550233
# ENSG00000163736    7447       679   85.392337   78.464313  ...   80.495375
# ENSG00000087086  821937     32296   43.064119   42.226038  ...   43.034129
# ENSG00000163220  186202     10159   36.166104   34.965024  ...   36.014145
# ENSG00000090382  323725     15500   34.801999   34.258216  ...   34.461091
# ...                 ...       ...         ...         ...  ...         ...
# ENSG00000171241      64        56    0.599725    0.599725  ...    0.583413
# ENSG00000149573      67        63    0.722642    0.599725  ...    0.831297
# ENSG00000122025     144       124    0.651807    0.599725  ...    0.650389
# ENSG00000237980      53        52    0.682438    0.599725  ...    0.684189
# ENSG00000158488      87        73    0.666333    0.599725  ...    0.614511
#
#                          37          38          39
# ENSG00000254709  321.476696  751.507723  358.442950
# ENSG00000163736   90.223068   85.562912   85.228175
# ENSG00000087086   43.092594   42.605875   43.514108
# ENSG00000163220   36.310537   35.723617   36.618340
# ENSG00000090382   35.131176   34.690716   34.916203
# ...                     ...         ...         ...
# ENSG00000171241    0.613986    0.528656    0.647995
# ENSG00000149573    0.649071    0.718847    0.724868
# ENSG00000122025    0.653850    0.694497    0.614593
# ENSG00000237980    0.680047    0.626383    0.728624
# ENSG00000158488    0.716838    0.704700    0.616995
#
# [12324 rows x 44 columns]
#
#
#  df_gene_stats.describe
#                 M_g           A_g
# count  12324.000000  12324.000000
# mean       1.475133      1.140886
# std        5.558065      3.130212
# min        0.599725      0.599725
# 1%         0.850722      0.734219
# 5%         0.961147      0.847594
# 10%        1.001918      0.896514
# 25%        1.070023      0.960231
# 50%        1.205582      1.012433
# 75%        1.460740      1.076668
# 90%        1.843678      1.207973
# 95%        2.310018      1.392840
# 99%        4.682070      2.815683
# max      594.080034    321.476696
#
#
#  df_selected_cells
#                      0      1   ...     38     39
# AAACATTGACGACT-1  False   True  ...  False   True
# AAACATTGACGGGA-1   True  False  ...   True  False
# AAACATTGCCGCTT-1   True  False  ...   True  False
# AAACATTGCTCATT-1   True  False  ...   True  False
# AAACCGTGCCCTCA-1  False   True  ...   True  False
# ...                 ...    ...  ...    ...    ...
# TTTGCATGCACTAG-6   True  False  ...  False   True
# TTTGCATGCCGAAT-6  False   True  ...   True  False
# TTTGCATGGAGGTG-6  False   True  ...   True  False
# TTTGCATGGATAAG-6  False   True  ...   True  False
# TTTGCATGGGCATT-6   True  False  ...   True  False
#
# [33148 rows x 40 columns]
#
#
#  df_residuals
#                  AAACATTGACGACT-1  AAACATTGACGGGA-1  ...  TTTGCATGGATAAG-6  \
# ENSG00000188290         -0.262512         -0.218455  ...         -0.243437
# ENSG00000187608         -0.973823         -0.810386  ...          1.311634
# ENSG00000186891         -0.200060         -0.166484  ...         -0.185522
# ENSG00000186827         -0.243831         -0.202909  ...         -0.226113
# ENSG00000242485         -0.523616         -0.435738  ...         -0.485567
# ...                           ...               ...  ...               ...
# ENSG00000198886         -0.292932         -0.115341  ...         -0.492043
# ENSG00000198786         -0.830685          0.755341  ...         -0.770322
# ENSG00000198695         -0.283729         -0.236111  ...         -0.263112
# ENSG00000198727         -0.497816          0.741555  ...         -1.313994
# ENSG00000220023         -0.327680         -0.272686  ...         -0.303869
#
#                  TTTGCATGGGCATT-6
# ENSG00000188290         -0.231283
# ENSG00000187608         -0.857975
# ENSG00000186891         -0.176260
# ENSG00000186827         -0.214824
# ENSG00000242485          1.706340
# ...                           ...
# ENSG00000198886          1.268995
# ENSG00000198786         -0.731864
# ENSG00000198695         -0.249976
# ENSG00000198727          3.917694
# ENSG00000220023         -0.288699
#
# [2000 rows x 33148 columns]

# %%
start_time = time.time()
df_DE_stats = DE_H_stats ( df_residuals, df_clusters )
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru DE_H_stats time: ',  f"{ elapsed:.1f}", ' seconds'  )

print ( '\n df_DE_stats' )
print ( df_DE_stats  )
print ( '\n\n df_DE_stats.describe' )
print ( df_DE_stats.describe ( percentiles=pctl_list ) )
# Out:
# function nru DE_H_stats time:  17.9  seconds
#
#  df_DE_stats
#                       H_stat        p_value
# gene
# ENSG00000188290  3720.977633   0.000000e+00
# ENSG00000187608  4386.485905   0.000000e+00
# ENSG00000186891  6657.565638   0.000000e+00
# ENSG00000186827  5760.829303   0.000000e+00
# ENSG00000242485  1229.230979  5.926914e-259
# ...                      ...            ...
# ENSG00000198886   562.224090  2.663456e-115
# ENSG00000198786   467.048822   6.481650e-95
# ENSG00000198695  5101.174901   0.000000e+00
# ENSG00000198727   829.069126  1.173326e-172
# ENSG00000220023  4695.130388   0.000000e+00
#
# [2000 rows x 2 columns]
#
#
#  df_DE_stats.describe
#              H_stat        p_value
# count   2000.000000   2.000000e+03
# mean    5306.776149   5.832519e-27
# std     3306.813950   2.608382e-25
# min      130.034890   0.000000e+00
# 1%       454.933253   0.000000e+00
# 5%      1037.704128   0.000000e+00
# 10%     1551.585011   0.000000e+00
# 25%     2861.710099   0.000000e+00
# 50%     5270.049803   0.000000e+00
# 75%     6986.448071   0.000000e+00
# 90%     7732.344431   0.000000e+00
# 95%    11070.737622  8.413440e-216
# 99%    18263.674281   3.893678e-92
# max    22236.157542   1.166504e-23

# %%
#### input to SCTransform

df_counts_sparse_gene_sel = df_counts_sparse.loc [ df_gene_stats.index ]
print ( ' df_counts_sparse_gene_sel:' )
print ( df_counts_sparse_gene_sel )
print ( '\n type( df_counts_sparse_gene_sel ) ', type ( df_counts_sparse_gene_sel ))
print ( '\n df_counts_sparse_gene_sel.sparse.density: ', df_counts_sparse_gene_sel.sparse.density)
# Out:
#  df_counts_sparse_gene_sel:
#                  AAACATTGACGACT-1  AAACATTGACGGGA-1  ...  TTTGCATGGATAAG-6  \
# ENSG00000254709                 0                 0  ...                 0
# ENSG00000163736                 0                 0  ...                 0
# ENSG00000087086                 3                 6  ...                 8
# ENSG00000163220                 0                 0  ...                 0
# ENSG00000090382                 1                 0  ...                 0
# ...                           ...               ...  ...               ...
# ENSG00000171241                 0                 0  ...                 0
# ENSG00000149573                 0                 0  ...                 0
# ENSG00000122025                 0                 0  ...                 0
# ENSG00000237980                 0                 0  ...                 0
# ENSG00000158488                 0                 0  ...                 0
#
#                  TTTGCATGGGCATT-6
# ENSG00000254709                 0
# ENSG00000163736                 0
# ENSG00000087086                 2
# ENSG00000163220                 0
# ENSG00000090382                 0
# ...                           ...
# ENSG00000171241                 0
# ENSG00000149573                 0
# ENSG00000122025                 0
# ENSG00000237980                 0
# ENSG00000158488                 0
#
# [12324 rows x 33148 columns]
#
#  type( df_counts_sparse_gene_sel )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse_gene_sel.sparse.density:  0.06191115396149818

# %%
scipy_csc_mat = df_counts_sparse_gene_sel.sparse.to_coo().tocsc() 
print ( ' scipy_csc_mat.shape: ' ,  scipy_csc_mat.shape )
print ( '\n scipy_csc_mat:\n' , scipy_csc_mat)
# Out:
#  scipy_csc_mat.shape:  (12324, 33148)
#
#  scipy_csc_mat:
#    (2, 0)	3
#   (4, 0)	1
#   (6, 0)	9
#   (10, 0)	89
#   (23, 0)	27
#   (29, 0)	8
#   (31, 0)	24
#   (43, 0)	1
#   (45, 0)	4
#   (50, 0)	1
#   (53, 0)	1
#   (54, 0)	1
#   (62, 0)	34
#   (63, 0)	2
#   (64, 0)	32
#   (66, 0)	22
#   (78, 0)	7
#   (79, 0)	15
#   (80, 0)	8
#   (82, 0)	13
#   (85, 0)	24
#   (86, 0)	29
#   (87, 0)	3
#   (88, 0)	17
#   (91, 0)	20
#   :	:
#   (8737, 33147)	1
#   (8874, 33147)	1
#   (8889, 33147)	1
#   (9020, 33147)	1
#   (9039, 33147)	1
#   (9142, 33147)	1
#   (9144, 33147)	1
#   (9357, 33147)	1
#   (9403, 33147)	1
#   (9434, 33147)	1
#   (9525, 33147)	1
#   (9561, 33147)	1
#   (9593, 33147)	1
#   (9600, 33147)	1
#   (9718, 33147)	1
#   (9760, 33147)	1
#   (9969, 33147)	1
#   (9976, 33147)	1
#   (10085, 33147)	1
#   (10101, 33147)	1
#   (10172, 33147)	1
#   (10316, 33147)	1
#   (10339, 33147)	1
#   (11122, 33147)	1
#   (11840, 33147)	1

# %%
gene_array = df_counts_sparse_gene_sel.index.values
print ( '\n\n  gene_array.shape:  ' ,  gene_array.shape )
print ( '\n gene_array: ' , gene_array)
# Out:
#   gene_array.shape:   (12324,)
#
#  gene_array:  ['ENSG00000254709' 'ENSG00000163736' 'ENSG00000087086' ...
#  'ENSG00000122025' 'ENSG00000237980' 'ENSG00000158488']

# %%
cell_array = df_counts_sparse_gene_sel.columns.values
print ( '\n\n  cell_array.shape:  ' ,  cell_array.shape )
print ( '\n cell_array: ' , cell_array)
# Out:
#   cell_array.shape:   (33148,)
#
#  cell_array:  ['AAACATTGACGACT-1' 'AAACATTGACGGGA-1' 'AAACATTGCCGCTT-1' ...
#  'TTTGCATGGAGGTG-6' 'TTTGCATGGATAAG-6' 'TTTGCATGGGCATT-6']

# %%
f = open( nru_dict_dsn, 'wb' )    
pickle.dump( nru_dict, f)           
f.close()       

df_DE_stats.to_pickle ( DE_stats_dsn )

  
f = open( counts_scipy_csc_dsn, 'wb' )    
pickle.dump( scipy_csc_mat, f)           
f.close()       

f = open( gene_array_dsn, 'wb' )    
pickle.dump( gene_array, f)           
f.close()       

f = open( cell_array_dsn, 'wb' )    
pickle.dump( cell_array, f)           
f.close()
