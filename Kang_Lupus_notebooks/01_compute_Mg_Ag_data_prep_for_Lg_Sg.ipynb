# %%
import pandas as pd
import numpy  as np

import pickle 

from pathlib import Path

import time


import sys
sys.path.append("D:/analyze_Pearson_residuals")

from  nru_DE import *


pd.set_option('display.max_columns', 5)

# %%
np.random.seed( 12345 )

# %%
#### user specified
data_folder = r"D:/analyze_Pearson_residuals/"

data_subfolder = "Kang_Lupus"

data_path = Path ( data_folder + data_subfolder )

# %%
# output data
nru_dict_pkl =  "nru_dict.pkl"
DE_stats_pkl = "DE_stats.pkl"

counts_scipy_csc_pkl  = "counts_scipy_csc.pkl"
gene_array_pkl  = "gene_array.pkl"
cell_array_pkl  = "cell_array.pkl"


# input data
counts_pkl = "counts_sparse.pkl" # sparse pandas data frame: cells in columns; genes in rows
clusters_pkl = "clusters.pkl"


 
# paths: output data
nru_dict_dsn = data_path / nru_dict_pkl
DE_stats_dsn = data_path / DE_stats_pkl

counts_scipy_csc_dsn = data_path / counts_scipy_csc_pkl
gene_array_dsn = data_path / gene_array_pkl 
cell_array_dsn = data_path / cell_array_pkl  



# paths: input data
counts_dsn = data_path / counts_pkl
clusters_dsn = data_path / clusters_pkl

# %%
pctl_list = [.01,.05, .10, .25, .5, .75, .90, .95, .99 ]

# %%
df_clusters = pd.read_pickle ( clusters_dsn )	
print ( ' df_clusters'  )
print ( '\n', df_clusters )

print ( '\n\n df_clusters.value_counts' )
print ( df_clusters['Cluster'].value_counts() )
# Out:
#  df_clusters
#
#                            Cluster
# barcode
# AAACATACAATGCC-1      CD4 T cells
# AAACATACATTTCC-1  CD14+ Monocytes
# AAACATACCAGAAA-1  CD14+ Monocytes
# AAACATACCAGCTA-1  CD14+ Monocytes
# AAACATACCATGCA-1      CD4 T cells
# ...                           ...
# TTTGCATGCTAAGC-1      CD4 T cells
# TTTGCATGGGACGA-1      CD4 T cells
# TTTGCATGGTGAGG-1      CD4 T cells
# TTTGCATGGTTTGG-1      CD4 T cells
# TTTGCATGTCTTAC-1      CD4 T cells
#
# [26820 rows x 1 columns]
#
#
#  df_clusters.value_counts
# CD4 T cells          11771
# CD14+ Monocytes       5517
# B cells               2735
# CD8 T cells           2557
# NK cells              2284
# FCGR3A+ Monocytes     1489
# Megakaryocytes         247
# Dendritic cells        220
# Name: Cluster, dtype: int64

# %%
df_counts_sparse = pd.read_pickle ( counts_dsn )
print ( ' df_counts_sparse:' )
print ( df_counts_sparse )
print ( '\n type( df_counts_sparse ) ', type ( df_counts_sparse ))
print ( '\n df_counts_sparse.sparse.density: ', df_counts_sparse.sparse.density)
# Out:
#  df_counts_sparse:
# barcode          AAACATACAATGCC-1  AAACATACATTTCC-1  ...  TTTGCATGGTTTGG-1  \
# ENSEMBL_ID                                           ...
# ENSG00000239945                 0                 0  ...                 0
# ENSG00000237683                 0                 0  ...                 0
# ENSG00000228463                 0                 0  ...                 0
# ENSG00000228327                 0                 0  ...                 0
# ENSG00000237491                 0                 0  ...                 0
# ...                           ...               ...  ...               ...
# ENSG00000160298                 0                 0  ...                 0
# ENSG00000160299                 0                 0  ...                 0
# ENSG00000160305                 0                 0  ...                 0
# ENSG00000160307                 0                 0  ...                 0
# ENSG00000160310                 0                 0  ...                 0
#
# barcode          TTTGCATGTCTTAC-1
# ENSEMBL_ID
# ENSG00000239945                 0
# ENSG00000237683                 0
# ENSG00000228463                 0
# ENSG00000228327                 0
# ENSG00000237491                 0
# ...                           ...
# ENSG00000160298                 0
# ENSG00000160299                 0
# ENSG00000160305                 0
# ENSG00000160307                 0
# ENSG00000160310                 0
#
# [18501 rows x 26820 columns]
#
#  type( df_counts_sparse )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse.sparse.density:  0.030668793887070857

# %%
start_time = time.time()
nru_dict = nru ( df_counts_sparse ) 
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru elapsed time: ',  f"{ elapsed:.1f}", ' seconds'  )
# Out:
# counts_sparse_selected_genes.shape:  (10619, 26820)
# counts_sparse_selected_csr.shape:  (10619, 26820)
# calculating sum of squares of Pearson residuals using all cells
# calculating sum of squares of Pearson residuals using cell sample  0
# calculating sum of squares of Pearson residuals using cell sample  1
# calculating sum of squares of Pearson residuals using cell sample  2
# calculating sum of squares of Pearson residuals using cell sample  3
# calculating sum of squares of Pearson residuals using cell sample  4
# calculating sum of squares of Pearson residuals using cell sample  5
# calculating sum of squares of Pearson residuals using cell sample  6
# calculating sum of squares of Pearson residuals using cell sample  7
# calculating sum of squares of Pearson residuals using cell sample  8
# calculating sum of squares of Pearson residuals using cell sample  9
# calculating sum of squares of Pearson residuals using cell sample  10
# calculating sum of squares of Pearson residuals using cell sample  11
# calculating sum of squares of Pearson residuals using cell sample  12
# calculating sum of squares of Pearson residuals using cell sample  13
# calculating sum of squares of Pearson residuals using cell sample  14
# calculating sum of squares of Pearson residuals using cell sample  15
# calculating sum of squares of Pearson residuals using cell sample  16
# calculating sum of squares of Pearson residuals using cell sample  17
# calculating sum of squares of Pearson residuals using cell sample  18
# calculating sum of squares of Pearson residuals using cell sample  19
# calculating sum of squares of Pearson residuals using cell sample  20
# calculating sum of squares of Pearson residuals using cell sample  21
# calculating sum of squares of Pearson residuals using cell sample  22
# calculating sum of squares of Pearson residuals using cell sample  23
# calculating sum of squares of Pearson residuals using cell sample  24
# calculating sum of squares of Pearson residuals using cell sample  25
# calculating sum of squares of Pearson residuals using cell sample  26
# calculating sum of squares of Pearson residuals using cell sample  27
# calculating sum of squares of Pearson residuals using cell sample  28
# calculating sum of squares of Pearson residuals using cell sample  29
# calculating sum of squares of Pearson residuals using cell sample  30
# calculating sum of squares of Pearson residuals using cell sample  31
# calculating sum of squares of Pearson residuals using cell sample  32
# calculating sum of squares of Pearson residuals using cell sample  33
# calculating sum of squares of Pearson residuals using cell sample  34
# calculating sum of squares of Pearson residuals using cell sample  35
# calculating sum of squares of Pearson residuals using cell sample  36
# calculating sum of squares of Pearson residuals using cell sample  37
# calculating sum of squares of Pearson residuals using cell sample  38
# calculating sum of squares of Pearson residuals using cell sample  39
# function nru elapsed time:  80.4  seconds

# %%
df_gene_stats = nru_dict['df_gene_stats']
df_gene_stats.sort_values ( ['A_g'], ascending=False, inplace=True )
df_selected_cells = nru_dict['df_selected_cells']
df_residuals = nru_dict['df_residuals']

pd.set_option('display.max_columns', 8)
print ( '\n df_gene_stats'  )
print ( df_gene_stats  )
pd.set_option('display.max_columns', 5)

print ( '\n\n df_gene_stats.describe' )
print ( df_gene_stats[['M_g', 'A_g']].describe ( percentiles=pctl_list ) )

print ( '\n\n df_selected_cells'  )
print ( df_selected_cells ) 

print ( '\n\n df_residuals'  )
print ( df_residuals  )
# Out:
#  df_gene_stats
#                    count  nz_cells         M_g         A_g  ...          36  \
# ENSG00000244734   125215      2432  618.223412  583.983476  ...  596.567871
# ENSG00000188536    34906       614  187.010513  170.301545  ...  192.219099
# ENSG00000167996  2508767     26522   95.555335   94.267171  ...   95.988248
# ENSG00000206172    18566       380  105.145843   93.234056  ...  107.972367
# ENSG00000087086  1135906     23321   83.811940   82.854512  ...   84.363921
# ...                  ...       ...         ...         ...  ...         ...
# ENSG00000136492       74        71    0.709007    0.612331  ...    0.666820
# ENSG00000253593       54        50    0.722536    0.612331  ...    0.743436
# ENSG00000172379       92        82    0.717869    0.612331  ...    0.696231
# ENSG00000226004       80        73    0.690656    0.612331  ...    0.628593
# ENSG00000123643       57        54    0.743041    0.612331  ...    0.868902
#
#                          37          38          39
# ENSG00000244734  640.347962  619.280646  617.249748
# ENSG00000188536  181.143787  191.449626  182.862931
# ENSG00000167996   95.122889   96.053893   95.064007
# ENSG00000206172  101.953872  105.984683  104.364238
# ENSG00000087086   83.244955   83.573638   84.045445
# ...                     ...         ...         ...
# ENSG00000136492    0.766913    0.637216    0.808389
# ENSG00000253593    0.703146    0.753088    0.694161
# ENSG00000172379    0.735647    0.691467    0.740026
# ENSG00000226004    0.744556    0.726750    0.646433
# ENSG00000123643    0.657945    0.672763    0.815840
#
# [10619 rows x 44 columns]
#
#
#  df_gene_stats.describe
#                 M_g           A_g
# count  10619.000000  10619.000000
# mean       1.545574      1.299065
# std        9.113558      6.178635
# min        0.612331      0.612331
# 1%         0.772050      0.666219
# 5%         0.924491      0.808416
# 10%        1.023537      0.895367
# 25%        1.141486      1.024140
# 50%        1.248013      1.121165
# 75%        1.370817      1.204430
# 90%        1.590363      1.308610
# 95%        1.869607      1.509498
# 99%        4.272941      3.572999
# max      650.352779    583.983476
#
#
#  df_selected_cells
#                      0      1   ...     38     39
# AAACATACAATGCC-1  False   True  ...  False   True
# AAACATACATTTCC-1   True  False  ...   True  False
# AAACATACCAGAAA-1   True  False  ...   True  False
# AAACATACCAGCTA-1   True  False  ...  False   True
# AAACATACCATGCA-1  False   True  ...   True  False
# ...                 ...    ...  ...    ...    ...
# TTTGCATGCTAAGC-1   True  False  ...  False   True
# TTTGCATGGGACGA-1   True  False  ...   True  False
# TTTGCATGGTGAGG-1  False   True  ...   True  False
# TTTGCATGGTTTGG-1   True  False  ...  False   True
# TTTGCATGTCTTAC-1  False   True  ...  False   True
#
# [26820 rows x 40 columns]
#
#
#  df_residuals
#                  AAACATACAATGCC-1  AAACATACATTTCC-1  ...  TTTGCATGGTTTGG-1  \
# ENSG00000188976         -0.309356         -0.363462  ...         -0.184960
# ENSG00000188290         -0.494381         -0.580847  ...         -0.295585
# ENSG00000187608         -5.027882         -5.907248  ...         -0.344865
# ENSG00000186891         -0.314147         -0.369091  ...         -0.187825
# ENSG00000186827         -0.309093         -0.363152  ...         -0.184803
# ...                           ...               ...  ...               ...
# ENSG00000160213         -1.201684          0.713007  ...         -0.718473
# ENSG00000184787         -0.197340         -0.231854  ...         -0.117987
# ENSG00000160305         -0.155815         -0.183067  ...         -0.093160
# ENSG00000160307         -0.128497         -0.150971  ...         -0.076827
# ENSG00000160310         -0.571052         -0.670928  ...         -0.341425
#
#                  TTTGCATGTCTTAC-1
# ENSG00000188976         -0.212338
# ENSG00000188290         -0.339337
# ENSG00000187608         -2.581779
# ENSG00000186891         -0.215627
# ENSG00000186827         23.355278
# ...                           ...
# ENSG00000160213         -0.824820
# ENSG00000184787         -0.135452
# ENSG00000160305         -0.106949
# ENSG00000160307         -0.088199
# ENSG00000160310         -0.391963
#
# [2000 rows x 26820 columns]

# %%
start_time = time.time()
df_DE_stats = DE_H_stats ( df_residuals, df_clusters )
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru DE_H_stats time: ',  f"{ elapsed:.1f}", ' seconds'  )

print ( '\n df_DE_stats' )
print ( df_DE_stats  )
print ( '\n\n df_DE_stats.describe' )
print ( df_DE_stats.describe ( percentiles=pctl_list ) )
# Out:
# function nru DE_H_stats time:  14.2  seconds
#
#  df_DE_stats
#                       H_stat        p_value
# gene
# ENSG00000188976  8109.056902   0.000000e+00
# ENSG00000188290  1954.229387   0.000000e+00
# ENSG00000187608   674.921319  1.757515e-141
# ENSG00000186891  9293.326120   0.000000e+00
# ENSG00000186827  8467.938881   0.000000e+00
# ...                      ...            ...
# ENSG00000160213  4386.347363   0.000000e+00
# ENSG00000184787  8408.714306   0.000000e+00
# ENSG00000160305  8369.738362   0.000000e+00
# ENSG00000160307  8738.791126   0.000000e+00
# ENSG00000160310  3799.367634   0.000000e+00
#
# [2000 rows x 2 columns]
#
#
#  df_DE_stats.describe
#              H_stat        p_value
# count   2000.000000   2.000000e+03
# mean    7105.195362   3.859758e-21
# std     2627.289100   1.726136e-19
# min       95.856989   0.000000e+00
# 1%       674.813295   0.000000e+00
# 5%      1418.376609   0.000000e+00
# 10%     2431.863063   0.000000e+00
# 25%     5893.432200   0.000000e+00
# 50%     8220.004372   0.000000e+00
# 75%     8677.505442   0.000000e+00
# 90%     8802.676219   0.000000e+00
# 95%     9594.106389  6.550081e-301
# 99%    13005.762377  5.482259e-141
# max    16524.491543   7.719517e-18

# %%
#### input to SCTransform

df_counts_sparse_gene_sel = df_counts_sparse.loc [ df_gene_stats.index ]
print ( ' df_counts_sparse_gene_sel:' )
print ( df_counts_sparse_gene_sel )
print ( '\n type( df_counts_sparse_gene_sel ) ', type ( df_counts_sparse_gene_sel ))
print ( '\n df_counts_sparse_gene_sel.sparse.density: ', df_counts_sparse_gene_sel.sparse.density)
# Out:
#  df_counts_sparse_gene_sel:
# barcode          AAACATACAATGCC-1  AAACATACATTTCC-1  ...  TTTGCATGGTTTGG-1  \
# ENSG00000244734                 0                 0  ...                 0
# ENSG00000188536                 0                 0  ...                 0
# ENSG00000167996                32               388  ...                 8
# ENSG00000206172                 0                 0  ...                 0
# ENSG00000087086                 0               279  ...                 4
# ...                           ...               ...  ...               ...
# ENSG00000136492                 0                 0  ...                 0
# ENSG00000253593                 0                 0  ...                 0
# ENSG00000172379                 0                 0  ...                 0
# ENSG00000226004                 0                 0  ...                 0
# ENSG00000123643                 0                 0  ...                 0
#
# barcode          TTTGCATGTCTTAC-1
# ENSG00000244734                 1
# ENSG00000188536                 0
# ENSG00000167996                40
# ENSG00000206172                 0
# ENSG00000087086                 0
# ...                           ...
# ENSG00000136492                 0
# ENSG00000253593                 0
# ENSG00000172379                 0
# ENSG00000226004                 0
# ENSG00000123643                 0
#
# [10619 rows x 26820 columns]
#
#  type( df_counts_sparse_gene_sel )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse_gene_sel.sparse.density:  0.053135530357661644

# %%
scipy_csc_mat = df_counts_sparse_gene_sel.sparse.to_coo().tocsc() 
print ( ' scipy_csc_mat.shape: ' ,  scipy_csc_mat.shape )
print ( '\n scipy_csc_mat:\n' , scipy_csc_mat)
# Out:
#  scipy_csc_mat.shape:  (10619, 26820)
#
#  scipy_csc_mat:
#    (2, 0)	32
#   (15, 0)	217
#   (16, 0)	89
#   (33, 0)	50
#   (35, 0)	27
#   (41, 0)	26
#   (42, 0)	19
#   (43, 0)	34
#   (44, 0)	2
#   (45, 0)	5
#   (47, 0)	19
#   (50, 0)	22
#   (53, 0)	20
#   (54, 0)	18
#   (56, 0)	22
#   (62, 0)	18
#   (67, 0)	19
#   (69, 0)	22
#   (75, 0)	19
#   (76, 0)	1
#   (78, 0)	21
#   (79, 0)	20
#   (80, 0)	2
#   (86, 0)	11
#   (90, 0)	20
#   :	:
#   (6993, 26819)	1
#   (7045, 26819)	1
#   (7137, 26819)	1
#   (7214, 26819)	1
#   (7364, 26819)	1
#   (7423, 26819)	1
#   (7462, 26819)	1
#   (7584, 26819)	1
#   (7622, 26819)	1
#   (7699, 26819)	1
#   (7718, 26819)	1
#   (7844, 26819)	1
#   (7960, 26819)	1
#   (8173, 26819)	1
#   (8321, 26819)	1
#   (8360, 26819)	1
#   (8440, 26819)	1
#   (8482, 26819)	1
#   (8965, 26819)	1
#   (8997, 26819)	1
#   (9354, 26819)	1
#   (9377, 26819)	1
#   (9389, 26819)	1
#   (9629, 26819)	1
#   (10259, 26819)	1

# %%
gene_array = df_counts_sparse_gene_sel.index.values
print ( '\n\n  gene_array.shape:  ' ,  gene_array.shape )
print ( '\n gene_array: ' , gene_array)
# Out:
#   gene_array.shape:   (10619,)
#
#  gene_array:  ['ENSG00000244734' 'ENSG00000188536' 'ENSG00000167996' ...
#  'ENSG00000172379' 'ENSG00000226004' 'ENSG00000123643']

# %%
cell_array = df_counts_sparse_gene_sel.columns.values
print ( '\n\n  cell_array.shape:  ' ,  cell_array.shape )
print ( '\n cell_array: ' , cell_array)
# Out:
#   cell_array.shape:   (26820,)
#
#  cell_array:  ['AAACATACAATGCC-1' 'AAACATACATTTCC-1' 'AAACATACCAGAAA-1' ...
#  'TTTGCATGGTGAGG-1' 'TTTGCATGGTTTGG-1' 'TTTGCATGTCTTAC-1']

# %%
f = open( nru_dict_dsn, 'wb' )    
pickle.dump( nru_dict, f)           
f.close()       

df_DE_stats.to_pickle ( DE_stats_dsn )

  
f = open( counts_scipy_csc_dsn, 'wb' )    
pickle.dump( scipy_csc_mat, f)           
f.close()       

f = open( gene_array_dsn, 'wb' )    
pickle.dump( gene_array, f)           
f.close()       

f = open( cell_array_dsn, 'wb' )    
pickle.dump( cell_array, f)           
f.close()
