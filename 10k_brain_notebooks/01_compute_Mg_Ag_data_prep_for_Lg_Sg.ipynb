# %%
import pandas as pd
import numpy  as np

import pickle 

from pathlib import Path

import time



pd.set_option('display.max_columns', 5)

# %%
np.random.seed( 12345 )

# %%
#### user specified

data_folder = "D:/analyze_Pearson_residuals/"

data_subfolder = "10k_brain"

data_path = Path ( data_folder + data_subfolder )


import sys
sys.path.append( data_folder )

from  nru_DE import *

# %%
# output data
nru_dict_pkl =  "nru_dict.pkl"
DE_stats_pkl = "DE_stats.pkl"

counts_scipy_csc_pkl  = "counts_scipy_csc.pkl"
gene_array_pkl  = "gene_array.pkl"
cell_array_pkl  = "cell_array.pkl"


# input data
counts_pkl = "counts_sparse.pkl" # sparse pandas data frame: cells in columns; genes in rows
clusters_pkl = "clusters.pkl"

 
# paths: output data
nru_dict_dsn = data_path / nru_dict_pkl
DE_stats_dsn = data_path / DE_stats_pkl

counts_scipy_csc_dsn = data_path / counts_scipy_csc_pkl
gene_array_dsn = data_path / gene_array_pkl 
cell_array_dsn = data_path / cell_array_pkl  



# paths: input data
counts_dsn = data_path / counts_pkl
clusters_dsn = data_path / clusters_pkl

# %%
pctl_list = [.01,.05, .10, .25, .5, .75, .90, .95, .99 ]

# %%
df_clusters = pd.read_pickle ( clusters_dsn )	
print ( ' df_clusters'  )
print ( '\n', df_clusters )

print ( '\n\n df_clusters.value_counts' )
print ( df_clusters['Cluster'].value_counts() )
# Out:
#  df_clusters
#
#                      Cluster
# Barcode
# AAACCCAAGCAACTCT-1        7
# AAACCCACACGCGGTT-1        2
# AAACCCACAGCATACT-1        3
# AAACCCACATACCATG-1        4
# AAACCCAGTCGCACAC-1        7
# ...                     ...
# TTTGTTGGTAGCTAAA-1        1
# TTTGTTGGTATCCCAA-1        2
# TTTGTTGGTCCGAAAG-1        2
# TTTGTTGGTTCAACGT-1        2
# TTTGTTGTCCGTTTCG-1        1
#
# [11843 rows x 1 columns]
#
#
#  df_clusters.value_counts
# 1     3274
# 2     2978
# 3     1820
# 4     1410
# 5      762
# 6      730
# 7      664
# 8       83
# 9       78
# 10      44
# Name: Cluster, dtype: int64

# %%
df_counts_sparse = pd.read_pickle ( counts_dsn )
print ( ' df_counts_sparse:' )
print ( df_counts_sparse )
print ( '\n type( df_counts_sparse ) ', type ( df_counts_sparse ))
print ( '\n df_counts_sparse.sparse.density: ', df_counts_sparse.sparse.density)
# Out:
#  df_counts_sparse:
#                     AAACCCAAGCAACTCT-1  AAACCCACACGCGGTT-1  ...  \
# ENSEMBL_ID                                                  ...
# ENSMUSG00000051951                   0                   0  ...
# ENSMUSG00000025900                   0                   0  ...
# ENSMUSG00000025902                   0                   0  ...
# ENSMUSG00000033845                   0                   2  ...
# ENSMUSG00000025903                   0                   0  ...
# ...                                ...                 ...  ...
# ENSMUSG00000094350                   0                   0  ...
# ENSMUSG00000079808                   0                   0  ...
# ENSMUSG00000095041                   0                   0  ...
# ENSMUSG00000063897                   0                   0  ...
# ENSMUSG00000095742                   0                   0  ...
#
#                     TTTGTTGGTTCAACGT-1  TTTGTTGTCCGTTTCG-1
# ENSEMBL_ID
# ENSMUSG00000051951                   0                   0
# ENSMUSG00000025900                   0                   0
# ENSMUSG00000025902                   0                   0
# ENSMUSG00000033845                   0                   0
# ENSMUSG00000025903                   0                   0
# ...                                ...                 ...
# ENSMUSG00000094350                   0                   0
# ENSMUSG00000079808                   0                   0
# ENSMUSG00000095041                   0                   5
# ENSMUSG00000063897                   0                   1
# ENSMUSG00000095742                   0                   0
#
# [21080 rows x 11843 columns]
#
#  type( df_counts_sparse )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse.sparse.density:  0.12626562164280586

# %%
start_time = time.time()
nru_dict = nru ( df_counts_sparse ) 
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru elapsed time: ',  f"{ elapsed:.1f}", ' seconds'  )
# Out:
# counts_sparse_selected_genes.shape:  (13817, 11843)
# counts_sparse_selected_csr.shape:  (13817, 11843)
# calculating sum of squares of Pearson residuals using all cells
# calculating sum of squares of Pearson residuals using cell sample  0
# calculating sum of squares of Pearson residuals using cell sample  1
# calculating sum of squares of Pearson residuals using cell sample  2
# calculating sum of squares of Pearson residuals using cell sample  3
# calculating sum of squares of Pearson residuals using cell sample  4
# calculating sum of squares of Pearson residuals using cell sample  5
# calculating sum of squares of Pearson residuals using cell sample  6
# calculating sum of squares of Pearson residuals using cell sample  7
# calculating sum of squares of Pearson residuals using cell sample  8
# calculating sum of squares of Pearson residuals using cell sample  9
# calculating sum of squares of Pearson residuals using cell sample  10
# calculating sum of squares of Pearson residuals using cell sample  11
# calculating sum of squares of Pearson residuals using cell sample  12
# calculating sum of squares of Pearson residuals using cell sample  13
# calculating sum of squares of Pearson residuals using cell sample  14
# calculating sum of squares of Pearson residuals using cell sample  15
# calculating sum of squares of Pearson residuals using cell sample  16
# calculating sum of squares of Pearson residuals using cell sample  17
# calculating sum of squares of Pearson residuals using cell sample  18
# calculating sum of squares of Pearson residuals using cell sample  19
# calculating sum of squares of Pearson residuals using cell sample  20
# calculating sum of squares of Pearson residuals using cell sample  21
# calculating sum of squares of Pearson residuals using cell sample  22
# calculating sum of squares of Pearson residuals using cell sample  23
# calculating sum of squares of Pearson residuals using cell sample  24
# calculating sum of squares of Pearson residuals using cell sample  25
# calculating sum of squares of Pearson residuals using cell sample  26
# calculating sum of squares of Pearson residuals using cell sample  27
# calculating sum of squares of Pearson residuals using cell sample  28
# calculating sum of squares of Pearson residuals using cell sample  29
# calculating sum of squares of Pearson residuals using cell sample  30
# calculating sum of squares of Pearson residuals using cell sample  31
# calculating sum of squares of Pearson residuals using cell sample  32
# calculating sum of squares of Pearson residuals using cell sample  33
# calculating sum of squares of Pearson residuals using cell sample  34
# calculating sum of squares of Pearson residuals using cell sample  35
# calculating sum of squares of Pearson residuals using cell sample  36
# calculating sum of squares of Pearson residuals using cell sample  37
# calculating sum of squares of Pearson residuals using cell sample  38
# calculating sum of squares of Pearson residuals using cell sample  39
# function nru elapsed time:  56.4  seconds

# %%
df_gene_stats = nru_dict['df_gene_stats']
df_gene_stats.sort_values ( ['A_g'], ascending=False, inplace=True )
df_selected_cells = nru_dict['df_selected_cells']
df_residuals = nru_dict['df_residuals']

pd.set_option('display.max_columns', 8)
print ( '\n df_gene_stats'  )
print ( df_gene_stats  )
pd.set_option('display.max_columns', 5)

print ( '\n\n df_gene_stats.describe' )
print ( df_gene_stats[['M_g', 'A_g']].describe ( percentiles=pctl_list ) )

print ( '\n\n df_selected_cells'  )
print ( df_selected_cells ) 

print ( '\n\n df_residuals'  )
print ( df_residuals  )
# Out:
#  df_gene_stats
#                       count  nz_cells          M_g          A_g  ...  \
# ENSMUSG00000052305  1039027      4111  4124.336945  4003.436265  ...
# ENSMUSG00000073940   275123      1357  1305.624180  1188.055973  ...
# ENSMUSG00000069919   183995       959   771.789797   749.206331  ...
# ENSMUSG00000069917   129468       916   542.570514   526.798715  ...
# ENSMUSG00000019874   136466      6156   154.696097   143.286862  ...
# ...                     ...       ...          ...          ...  ...
# ENSMUSG00000027075      124       118     1.112878     0.646999  ...
# ENSMUSG00000026389       70        52     1.134578     0.646999  ...
# ENSMUSG00000063021       59        57     0.973301     0.646999  ...
# ENSMUSG00000032204       59        59     0.894099     0.646999  ...
# ENSMUSG00000043629      115       107     0.950153     0.646999  ...
#
#                              36           37           38           39
# ENSMUSG00000052305  4142.580144  4099.022225  4141.087991  4107.265217
# ENSMUSG00000073940  1380.776335  1188.055973  1317.821734  1292.635092
# ENSMUSG00000069919   779.946978   760.357864   778.887496   764.385572
# ENSMUSG00000069917   550.398415   531.529833   547.762436   537.131338
# ENSMUSG00000019874   153.831846   155.608373   151.603896   157.625034
# ...                         ...          ...          ...          ...
# ENSMUSG00000027075     1.235255     0.986954     1.235736     0.983079
# ENSMUSG00000026389     1.319008     1.024583     1.197449     1.078297
# ENSMUSG00000063021     1.082758     0.880937     0.798772     1.152406
# ENSMUSG00000032204     0.998160     0.753281     0.875715     0.903911
# ENSMUSG00000043629     0.729066     1.190662     0.854766     1.103823
#
# [13817 rows x 44 columns]
#
#
#  df_gene_stats.describe
#                 M_g           A_g
# count  13817.000000  13817.000000
# mean       2.044074      1.797564
# std       37.863620     36.413637
# min        0.646999      0.646999
# 1%         0.859568      0.690944
# 5%         0.922065      0.809898
# 10%        0.954772      0.867606
# 25%        1.035079      0.944499
# 50%        1.168954      1.058721
# 75%        1.365103      1.225231
# 90%        1.838223      1.601801
# 95%        2.634773      2.222903
# 99%        7.874280      6.448638
# max     4124.336945   4003.436265
#
#
#  df_selected_cells
#                        0      1   ...     38     39
# AAACCCAAGCAACTCT-1  False   True  ...   True  False
# AAACCCACACGCGGTT-1   True  False  ...   True  False
# AAACCCACAGCATACT-1   True  False  ...   True  False
# AAACCCACATACCATG-1   True  False  ...   True  False
# AAACCCAGTCGCACAC-1  False   True  ...  False   True
# ...                   ...    ...  ...    ...    ...
# TTTGTTGGTAGCTAAA-1  False   True  ...  False   True
# TTTGTTGGTATCCCAA-1  False   True  ...  False   True
# TTTGTTGGTCCGAAAG-1  False   True  ...  False   True
# TTTGTTGGTTCAACGT-1   True  False  ...   True  False
# TTTGTTGTCCGTTTCG-1  False   True  ...  False   True
#
# [11843 rows x 40 columns]
#
#
#  df_residuals
#                     AAACCCAAGCAACTCT-1  AAACCCACACGCGGTT-1  ...  \
# ENSMUSG00000051951           -0.121008           -0.245192  ...
# ENSMUSG00000025902           -0.072269           -0.146436  ...
# ENSMUSG00000025909           -0.074738            6.451933  ...
# ENSMUSG00000056763           -0.369036            0.589563  ...
# ENSMUSG00000043716           -0.724136           -0.465320  ...
# ...                                ...                 ...  ...
# ENSMUSG00000065947           -0.716012            1.306235  ...
# ENSMUSG00000064363           -2.104575            3.239570  ...
# ENSMUSG00000064367           -0.673613            0.833033  ...
# ENSMUSG00000064370           -3.429400            4.276058  ...
# ENSMUSG00000095041           -0.272875           -0.552914  ...
#
#                     TTTGTTGGTTCAACGT-1  TTTGTTGTCCGTTTCG-1
# ENSMUSG00000051951           -0.250933           -0.207165
# ENSMUSG00000025902           -0.149864           -0.123725
# ENSMUSG00000025909           -0.154983           -0.127951
# ENSMUSG00000056763           -0.765269            0.951016
# ENSMUSG00000043716           -0.588389           -0.391957
# ...                                ...                 ...
# ENSMUSG00000065947           -0.137799            1.221549
# ENSMUSG00000064363           -0.239826            2.502944
# ENSMUSG00000064367           -0.680981            0.581044
# ENSMUSG00000064370           -0.502546            2.815451
# ENSMUSG00000095041           -0.565859           10.235779
#
# [2000 rows x 11843 columns]

# %%
start_time = time.time()
df_DE_stats = DE_H_stats ( df_residuals, df_clusters )
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru DE_H_stats time: ',  f"{ elapsed:.1f}", ' seconds'  )

print ( '\n df_DE_stats' )
print ( df_DE_stats  )
print ( '\n\n df_DE_stats.describe' )
print ( df_DE_stats.describe ( percentiles=pctl_list ) )
# Out:
# function nru DE_H_stats time:  10.8  seconds
#
#  df_DE_stats
#                          H_stat        p_value
# gene
# ENSMUSG00000051951  4974.891288   0.000000e+00
# ENSMUSG00000025902  6851.955509   0.000000e+00
# ENSMUSG00000025909  5939.752735   0.000000e+00
# ENSMUSG00000056763   585.248576  3.065746e-120
# ENSMUSG00000043716  2211.075812   0.000000e+00
# ...                         ...            ...
# ENSMUSG00000065947  1412.445751  1.581644e-298
# ENSMUSG00000064363  2612.746226   0.000000e+00
# ENSMUSG00000064367   949.196396  1.546416e-198
# ENSMUSG00000064370  2868.423229   0.000000e+00
# ENSMUSG00000095041  1888.593359   0.000000e+00
#
# [2000 rows x 2 columns]
#
#
#  df_DE_stats.describe
#             H_stat        p_value
# count  2000.000000   2.000000e+03
# mean   3941.604064   1.735623e-61
# std    2035.315046   7.761940e-60
# min     294.700811   0.000000e+00
# 1%      614.137292   0.000000e+00
# 5%      898.164567   0.000000e+00
# 10%    1205.248145   0.000000e+00
# 25%    2090.189025   0.000000e+00
# 50%    3913.376548   0.000000e+00
# 75%    5973.533070   0.000000e+00
# 90%    6631.385837  1.491884e-253
# 95%    6770.734876  1.537932e-187
# 99%    6869.851796  2.972016e-126
# max    7454.899149   3.471245e-58

# %%
#### input to SCTransform

df_counts_sparse_gene_sel = df_counts_sparse.loc [ df_gene_stats.index ]
print ( ' df_counts_sparse_gene_sel:' )
print ( df_counts_sparse_gene_sel )
print ( '\n type( df_counts_sparse_gene_sel ) ', type ( df_counts_sparse_gene_sel ))
print ( '\n df_counts_sparse_gene_sel.sparse.density: ', df_counts_sparse_gene_sel.sparse.density)
# Out:
#  df_counts_sparse_gene_sel:
#                     AAACCCAAGCAACTCT-1  AAACCCACACGCGGTT-1  ...  \
# ENSMUSG00000052305                   0                   0  ...
# ENSMUSG00000073940                   0                   0  ...
# ENSMUSG00000069919                   0                   0  ...
# ENSMUSG00000069917                   0                   0  ...
# ENSMUSG00000019874                  20                   2  ...
# ...                                ...                 ...  ...
# ENSMUSG00000027075                   0                   0  ...
# ENSMUSG00000026389                   0                   0  ...
# ENSMUSG00000063021                   0                   0  ...
# ENSMUSG00000032204                   0                   0  ...
# ENSMUSG00000043629                   0                   0  ...
#
#                     TTTGTTGGTTCAACGT-1  TTTGTTGTCCGTTTCG-1
# ENSMUSG00000052305                   0                   0
# ENSMUSG00000073940                   0                   0
# ENSMUSG00000069919                   0                   0
# ENSMUSG00000069917                   0                   0
# ENSMUSG00000019874                   6                   0
# ...                                ...                 ...
# ENSMUSG00000027075                   0                   0
# ENSMUSG00000026389                   0                   0
# ENSMUSG00000063021                   0                   0
# ENSMUSG00000032204                   0                   0
# ENSMUSG00000043629                   0                   0
#
# [13817 rows x 11843 columns]
#
#  type( df_counts_sparse_gene_sel )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse_gene_sel.sparse.density:  0.19216543949951553

# %%
scipy_csc_mat = df_counts_sparse_gene_sel.sparse.to_coo().tocsc() 
print ( ' scipy_csc_mat.shape: ' ,  scipy_csc_mat.shape )
print ( '\n scipy_csc_mat:\n' , scipy_csc_mat)
# Out:
#  scipy_csc_mat.shape:  (13817, 11843)
#
#  scipy_csc_mat:
#    (4, 0)	20
#   (6, 0)	2
#   (9, 0)	2
#   (12, 0)	8
#   (13, 0)	21
#   (15, 0)	1
#   (20, 0)	1
#   (22, 0)	15
#   (24, 0)	2
#   (25, 0)	1
#   (40, 0)	3
#   (46, 0)	4
#   (47, 0)	3
#   (60, 0)	2
#   (63, 0)	11
#   (70, 0)	3
#   (71, 0)	2
#   (76, 0)	1
#   (88, 0)	4
#   (97, 0)	1
#   (102, 0)	1
#   (110, 0)	1
#   (112, 0)	7
#   (115, 0)	2
#   (116, 0)	15
#   :	:
#   (12660, 11842)	1
#   (12663, 11842)	1
#   (12675, 11842)	1
#   (12717, 11842)	1
#   (12737, 11842)	1
#   (12740, 11842)	1
#   (12741, 11842)	1
#   (12782, 11842)	1
#   (12830, 11842)	1
#   (12834, 11842)	1
#   (12906, 11842)	1
#   (12931, 11842)	1
#   (12952, 11842)	1
#   (12954, 11842)	1
#   (12956, 11842)	1
#   (12978, 11842)	1
#   (13011, 11842)	1
#   (13015, 11842)	1
#   (13024, 11842)	1
#   (13044, 11842)	1
#   (13075, 11842)	1
#   (13081, 11842)	1
#   (13265, 11842)	1
#   (13516, 11842)	1
#   (13537, 11842)	1

# %%
gene_array = df_counts_sparse_gene_sel.index.values
print ( '\n\n  gene_array.shape:  ' ,  gene_array.shape )
print ( '\n gene_array: ' , gene_array)
# Out:
#   gene_array.shape:   (13817,)
#
#  gene_array:  ['ENSMUSG00000052305' 'ENSMUSG00000073940' 'ENSMUSG00000069919' ...
#  'ENSMUSG00000063021' 'ENSMUSG00000032204' 'ENSMUSG00000043629']

# %%
cell_array = df_counts_sparse_gene_sel.columns.values
print ( '\n\n  cell_array.shape:  ' ,  cell_array.shape )
print ( '\n cell_array: ' , cell_array)
# Out:
#   cell_array.shape:   (11843,)
#
#  cell_array:  ['AAACCCAAGCAACTCT-1' 'AAACCCACACGCGGTT-1' 'AAACCCACAGCATACT-1' ...
#  'TTTGTTGGTCCGAAAG-1' 'TTTGTTGGTTCAACGT-1' 'TTTGTTGTCCGTTTCG-1']

# %%
f = open( nru_dict_dsn, 'wb' )    
pickle.dump( nru_dict, f)           
f.close()       

df_DE_stats.to_pickle ( DE_stats_dsn )

  
f = open( counts_scipy_csc_dsn, 'wb' )    
pickle.dump( scipy_csc_mat, f)           
f.close()       

f = open( gene_array_dsn, 'wb' )    
pickle.dump( gene_array, f)           
f.close()       

f = open( cell_array_dsn, 'wb' )    
pickle.dump( cell_array, f)           
f.close()
