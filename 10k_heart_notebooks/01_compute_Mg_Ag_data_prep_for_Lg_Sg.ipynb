# %%
import pandas as pd
import numpy  as np

import pickle 

from pathlib import Path

import time


import sys
sys.path.append("D:/analyze_Pearson_residuals")

from  nru_DE import *


pd.set_option('display.max_columns', 5)

# %%
np.random.seed( 12345 )

# %%
#### user specified
data_folder = r"D:/analyze_Pearson_residuals/"

data_subfolder = "10k_heart"

data_path = Path ( data_folder + data_subfolder )

# %%
# output data
nru_dict_pkl =  "nru_dict.pkl"
DE_stats_pkl = "DE_stats.pkl"

counts_scipy_csc_pkl  = "counts_scipy_csc.pkl"
gene_array_pkl  = "gene_array.pkl"
cell_array_pkl  = "cell_array.pkl"


# input data
counts_pkl = "counts_sparse.pkl" # sparse pandas data frame: cells in columns; genes in rows
clusters_pkl = "clusters.pkl"


 
# paths: output data
nru_dict_dsn = data_path / nru_dict_pkl
DE_stats_dsn = data_path / DE_stats_pkl

counts_scipy_csc_dsn = data_path / counts_scipy_csc_pkl
gene_array_dsn = data_path / gene_array_pkl 
cell_array_dsn = data_path / cell_array_pkl  



# paths: input data
counts_dsn = data_path / counts_pkl
clusters_dsn = data_path / clusters_pkl

# %%
pctl_list = [.01,.05, .10, .25, .5, .75, .90, .95, .99 ]

# %%
df_clusters = pd.read_pickle ( clusters_dsn )	
print ( ' df_clusters'  )
print ( '\n', df_clusters )

print ( '\n\n df_clusters.value_counts' )
print ( df_clusters['Cluster'].value_counts() )
# Out:
#  df_clusters
#
#                      Cluster
# Barcode
# AAACCCAAGCGAGTCA-1        3
# AAACCCAAGGTCATTC-1        6
# AAACCCACACTGTGTA-1        5
# AAACCCACATATCTGG-1        5
# AAACCCACATCAACCA-1        9
# ...                     ...
# TTTGGTTTCTGTACAG-1        1
# TTTGTTGAGCTTTCCC-1        3
# TTTGTTGGTGCTCTCT-1        1
# TTTGTTGTCCCAGGAC-1        7
# TTTGTTGTCTTCGACC-1        3
#
# [7713 rows x 1 columns]
#
#
#  df_clusters.value_counts
# 1     1899
# 2     1542
# 3     1456
# 4     1147
# 5      477
# 6      420
# 7      279
# 8      261
# 9      227
# 10       5
# Name: Cluster, dtype: int64

# %%
df_counts_sparse = pd.read_pickle ( counts_dsn )
print ( ' df_counts_sparse:' )
print ( df_counts_sparse )
print ( '\n type( df_counts_sparse ) ', type ( df_counts_sparse ))
print ( '\n df_counts_sparse.sparse.density: ', df_counts_sparse.sparse.density)
# Out:
#  df_counts_sparse:
#                     AAACCCAAGCGAGTCA-1  AAACCCAAGGTCATTC-1  ...  \
# ENSEMBL_ID                                                  ...
# ENSMUSG00000051951                   0                   0  ...
# ENSMUSG00000102343                   0                   0  ...
# ENSMUSG00000025900                   0                   0  ...
# ENSMUSG00000025902                   0                   0  ...
# ENSMUSG00000033845                   0                   1  ...
# ...                                ...                 ...  ...
# ENSMUSG00000079800                   0                   0  ...
# ENSMUSG00000079808                   0                   0  ...
# ENSMUSG00000095041                   0                   0  ...
# ENSMUSG00000063897                   0                   0  ...
# ENSMUSG00000095742                   0                   0  ...
#
#                     TTTGTTGTCCCAGGAC-1  TTTGTTGTCTTCGACC-1
# ENSEMBL_ID
# ENSMUSG00000051951                   0                   0
# ENSMUSG00000102343                   0                   0
# ENSMUSG00000025900                   0                   0
# ENSMUSG00000025902                   0                   0
# ENSMUSG00000033845                   0                   0
# ...                                ...                 ...
# ENSMUSG00000079800                   0                   0
# ENSMUSG00000079808                   0                   0
# ENSMUSG00000095041                   0                   0
# ENSMUSG00000063897                   0                   0
# ENSMUSG00000095742                   0                   0
#
# [22621 rows x 7713 columns]
#
#  type( df_counts_sparse )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse.sparse.density:  0.10918232756590222

# %%
start_time = time.time()
nru_dict = nru ( df_counts_sparse ) 
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru elapsed time: ',  f"{ elapsed:.1f}", ' seconds'  )
# Out:
# counts_sparse_selected_genes.shape:  (14472, 7713)
# counts_sparse_selected_csr.shape:  (14472, 7713)
# calculating sum of squares of Pearson residuals using all cells
# calculating sum of squares of Pearson residuals using cell sample  0
# calculating sum of squares of Pearson residuals using cell sample  1
# calculating sum of squares of Pearson residuals using cell sample  2
# calculating sum of squares of Pearson residuals using cell sample  3
# calculating sum of squares of Pearson residuals using cell sample  4
# calculating sum of squares of Pearson residuals using cell sample  5
# calculating sum of squares of Pearson residuals using cell sample  6
# calculating sum of squares of Pearson residuals using cell sample  7
# calculating sum of squares of Pearson residuals using cell sample  8
# calculating sum of squares of Pearson residuals using cell sample  9
# calculating sum of squares of Pearson residuals using cell sample  10
# calculating sum of squares of Pearson residuals using cell sample  11
# calculating sum of squares of Pearson residuals using cell sample  12
# calculating sum of squares of Pearson residuals using cell sample  13
# calculating sum of squares of Pearson residuals using cell sample  14
# calculating sum of squares of Pearson residuals using cell sample  15
# calculating sum of squares of Pearson residuals using cell sample  16
# calculating sum of squares of Pearson residuals using cell sample  17
# calculating sum of squares of Pearson residuals using cell sample  18
# calculating sum of squares of Pearson residuals using cell sample  19
# calculating sum of squares of Pearson residuals using cell sample  20
# calculating sum of squares of Pearson residuals using cell sample  21
# calculating sum of squares of Pearson residuals using cell sample  22
# calculating sum of squares of Pearson residuals using cell sample  23
# calculating sum of squares of Pearson residuals using cell sample  24
# calculating sum of squares of Pearson residuals using cell sample  25
# calculating sum of squares of Pearson residuals using cell sample  26
# calculating sum of squares of Pearson residuals using cell sample  27
# calculating sum of squares of Pearson residuals using cell sample  28
# calculating sum of squares of Pearson residuals using cell sample  29
# calculating sum of squares of Pearson residuals using cell sample  30
# calculating sum of squares of Pearson residuals using cell sample  31
# calculating sum of squares of Pearson residuals using cell sample  32
# calculating sum of squares of Pearson residuals using cell sample  33
# calculating sum of squares of Pearson residuals using cell sample  34
# calculating sum of squares of Pearson residuals using cell sample  35
# calculating sum of squares of Pearson residuals using cell sample  36
# calculating sum of squares of Pearson residuals using cell sample  37
# calculating sum of squares of Pearson residuals using cell sample  38
# calculating sum of squares of Pearson residuals using cell sample  39
# function nru elapsed time:  32.4  seconds

# %%
df_gene_stats = nru_dict['df_gene_stats']
df_gene_stats.sort_values ( ['A_g'], ascending=False, inplace=True )
df_selected_cells = nru_dict['df_selected_cells']
df_residuals = nru_dict['df_residuals']

pd.set_option('display.max_columns', 8)
print ( '\n df_gene_stats'  )
print ( df_gene_stats  )
pd.set_option('display.max_columns', 5)

print ( '\n\n df_gene_stats.describe' )
print ( df_gene_stats[['M_g', 'A_g']].describe ( percentiles=pctl_list ) )

print ( '\n\n df_selected_cells'  )
print ( df_selected_cells ) 

print ( '\n\n df_residuals'  )
print ( df_residuals  )
# Out:
#  df_gene_stats
#                       count  nz_cells          M_g          A_g  ...  \
# ENSMUSG00000052305  2524099      6202  5632.169642  5431.424034  ...
# ENSMUSG00000069919   622334      2897  1465.445393  1391.789121  ...
# ENSMUSG00000073940   494719      2925  1444.191949  1383.160300  ...
# ENSMUSG00000069917   435238      2625  1017.600302   971.366465  ...
# ENSMUSG00000038791    58621       802  1390.212454   603.920335  ...
# ...                     ...       ...          ...          ...  ...
# ENSMUSG00000020905       70        54     0.611757     0.443594  ...
# ENSMUSG00000027313       55        50     0.580312     0.443594  ...
# ENSMUSG00000104861       61        55     0.552270     0.443594  ...
# ENSMUSG00000041144       71        56     0.650507     0.443594  ...
# ENSMUSG00000000154       62        58     0.535058     0.443594  ...
#
#                              36           37           38           39
# ENSMUSG00000052305  5721.392628  5545.057621  5570.336160  5692.161314
# ENSMUSG00000069919  1493.955882  1437.576305  1479.282582  1451.521186
# ENSMUSG00000073940  1479.362464  1409.039947  1448.962321  1439.467700
# ENSMUSG00000069917  1036.415732   999.202620  1024.950490  1010.126234
# ENSMUSG00000038791  1390.344839  1381.907859  1106.549853  1632.198005
# ...                         ...          ...          ...          ...
# ENSMUSG00000020905     0.722300     0.554841     0.424284     0.771518
# ENSMUSG00000027313     0.676285     0.506005     0.523916     0.675913
# ENSMUSG00000104861     0.578495     0.520445     0.560733     0.543194
# ENSMUSG00000041144     0.594995     0.686563     0.496117     0.810646
# ENSMUSG00000000154     0.639932     0.424962     0.568553     0.503392
#
# [14472 rows x 44 columns]
#
#
#  df_gene_stats.describe
#                 M_g           A_g
# count  14472.000000  14472.000000
# mean       3.227567      2.597151
# std       53.050587     49.427532
# min        0.443594      0.443594
# 1%         0.689651      0.515163
# 5%         0.818420      0.643734
# 10%        0.887477      0.730258
# 25%        1.019792      0.879153
# 50%        1.268172      1.084766
# 75%        1.779943      1.484565
# 90%        3.155482      2.475259
# 95%        5.250088      3.936612
# 99%       21.395956     14.116029
# max     5632.169642   5431.424034
#
#
#  df_selected_cells
#                        0      1   ...     38     39
# AAACCCAAGCGAGTCA-1  False   True  ...  False   True
# AAACCCAAGGTCATTC-1   True  False  ...  False   True
# AAACCCACACTGTGTA-1   True  False  ...   True  False
# AAACCCACATATCTGG-1   True  False  ...   True  False
# AAACCCACATCAACCA-1  False   True  ...   True  False
# ...                   ...    ...  ...    ...    ...
# TTTGGTTTCTGTACAG-1  False   True  ...  False   True
# TTTGTTGAGCTTTCCC-1  False   True  ...  False   True
# TTTGTTGGTGCTCTCT-1  False   True  ...   True  False
# TTTGTTGTCCCAGGAC-1   True  False  ...   True  False
# TTTGTTGTCTTCGACC-1   True  False  ...   True  False
#
# [7713 rows x 40 columns]
#
#
#  df_residuals
#                     AAACCCAAGCGAGTCA-1  AAACCCAAGGTCATTC-1  ...  \
# ENSMUSG00000025902           -0.085148           -0.288922  ...
# ENSMUSG00000090031           -0.103442           -0.350995  ...
# ENSMUSG00000056763           -0.296117           -1.004775  ...
# ENSMUSG00000016918           -0.287292           17.489928  ...
# ENSMUSG00000025930           -0.104201           -0.353570  ...
# ...                                ...                 ...  ...
# ENSMUSG00000064363           -0.305249           -3.305995  ...
# ENSMUSG00000064367            0.638784           -1.228728  ...
# ENSMUSG00000064368           -0.262778            0.229870  ...
# ENSMUSG00000064370           -0.904076           -5.660851  ...
# ENSMUSG00000095041           -0.302640           -1.026907  ...
#
#                     TTTGTTGTCCCAGGAC-1  TTTGTTGTCTTCGACC-1
# ENSMUSG00000025902           -0.272828           -0.162931
# ENSMUSG00000090031           -0.331444           -0.197935
# ENSMUSG00000056763            0.105149           -0.566619
# ENSMUSG00000016918           -0.920529           -0.549732
# ENSMUSG00000025930           -0.333876           -0.199388
# ...                                ...                 ...
# ENSMUSG00000064363           -0.570984           -4.988224
# ENSMUSG00000064367           -1.137363           -1.238488
# ENSMUSG00000064368           -0.841981           -0.502824
# ENSMUSG00000064370           -2.087374           -5.834327
# ENSMUSG00000095041           -0.969705           -0.579100
#
# [2000 rows x 7713 columns]

# %%
start_time = time.time()
df_DE_stats = DE_H_stats ( df_residuals, df_clusters )
end_time = time.time()
elapsed = end_time - start_time
print ( 'function nru DE_H_stats time: ',  f"{ elapsed:.1f}", ' seconds'  )

print ( '\n df_DE_stats' )
print ( df_DE_stats  )
print ( '\n\n df_DE_stats.describe' )
print ( df_DE_stats.describe ( percentiles=pctl_list ) )
# Out:
# function nru DE_H_stats time:  9.1  seconds
#
#  df_DE_stats
#                          H_stat        p_value
# gene
# ENSMUSG00000025902  4188.729726   0.000000e+00
# ENSMUSG00000090031  3026.429426   0.000000e+00
# ENSMUSG00000056763   686.334852  5.988892e-142
# ENSMUSG00000016918  3681.119397   0.000000e+00
# ENSMUSG00000025930  4050.502784   0.000000e+00
# ...                         ...            ...
# ENSMUSG00000064363  2437.332877   0.000000e+00
# ENSMUSG00000064367  2328.901485   0.000000e+00
# ENSMUSG00000064368   875.458531  1.198531e-182
# ENSMUSG00000064370  2502.629687   0.000000e+00
# ENSMUSG00000095041   901.155192  3.487907e-188
#
# [2000 rows x 2 columns]
#
#
#  df_DE_stats.describe
#             H_stat        p_value
# count  2000.000000   2.000000e+03
# mean   3011.641547   8.115694e-66
# std    1173.665187   3.629449e-64
# min     315.107357   0.000000e+00
# 1%      637.989653   0.000000e+00
# 5%      983.346292   0.000000e+00
# 10%    1307.387853   0.000000e+00
# 25%    2037.381000   0.000000e+00
# 50%    3230.635604   0.000000e+00
# 75%    4010.815239   0.000000e+00
# 90%    4372.806259  8.000805e-276
# 95%    4543.869373  6.720440e-206
# 99%    5043.409629  1.649140e-131
# max    5526.846687   1.623139e-62

# %%
#### input to SCTransform

df_counts_sparse_gene_sel = df_counts_sparse.loc [ df_gene_stats.index ]
print ( ' df_counts_sparse_gene_sel:' )
print ( df_counts_sparse_gene_sel )
print ( '\n type( df_counts_sparse_gene_sel ) ', type ( df_counts_sparse_gene_sel ))
print ( '\n df_counts_sparse_gene_sel.sparse.density: ', df_counts_sparse_gene_sel.sparse.density)
# Out:
#  df_counts_sparse_gene_sel:
#                     AAACCCAAGCGAGTCA-1  AAACCCAAGGTCATTC-1  ...  \
# ENSMUSG00000052305                 823                   3  ...
# ENSMUSG00000069919                 268                   0  ...
# ENSMUSG00000073940                  33                   0  ...
# ENSMUSG00000069917                 165                   0  ...
# ENSMUSG00000038791                   0                   1  ...
# ...                                ...                 ...  ...
# ENSMUSG00000020905                   0                   0  ...
# ENSMUSG00000027313                   0                   0  ...
# ENSMUSG00000104861                   0                   0  ...
# ENSMUSG00000041144                   0                   0  ...
# ENSMUSG00000000154                   0                   0  ...
#
#                     TTTGTTGTCCCAGGAC-1  TTTGTTGTCTTCGACC-1
# ENSMUSG00000052305                   3                2913
# ENSMUSG00000069919                   1                 963
# ENSMUSG00000073940                   1                 571
# ENSMUSG00000069917                   0                 686
# ENSMUSG00000038791                   0                   0
# ...                                ...                 ...
# ENSMUSG00000020905                   0                   0
# ENSMUSG00000027313                   0                   0
# ENSMUSG00000104861                   0                   0
# ENSMUSG00000041144                   0                   0
# ENSMUSG00000000154                   0                   0
#
# [14472 rows x 7713 columns]
#
#  type( df_counts_sparse_gene_sel )  <class 'pandas.core.frame.DataFrame'>
#
#  df_counts_sparse_gene_sel.sparse.density:  0.16982196140033945

# %%
scipy_csc_mat = df_counts_sparse_gene_sel.sparse.to_coo().tocsc() 
print ( ' scipy_csc_mat.shape: ' ,  scipy_csc_mat.shape )
print ( '\n scipy_csc_mat:\n' , scipy_csc_mat)
# Out:
#  scipy_csc_mat.shape:  (14472, 7713)
#
#  scipy_csc_mat:
#    (0, 0)	823
#   (1, 0)	268
#   (2, 0)	33
#   (3, 0)	165
#   (9, 0)	17
#   (10, 0)	12
#   (11, 0)	12
#   (12, 0)	1
#   (13, 0)	5
#   (19, 0)	1
#   (27, 0)	7
#   (28, 0)	3
#   (32, 0)	4
#   (35, 0)	1
#   (42, 0)	6
#   (46, 0)	6
#   (59, 0)	1
#   (84, 0)	1
#   (90, 0)	2
#   (101, 0)	1
#   (121, 0)	3
#   (124, 0)	1
#   (144, 0)	10
#   (145, 0)	1
#   (171, 0)	1
#   :	:
#   (6837, 7712)	1
#   (6873, 7712)	1
#   (7345, 7712)	1
#   (7414, 7712)	1
#   (7638, 7712)	1
#   (7811, 7712)	1
#   (7934, 7712)	2
#   (8178, 7712)	1
#   (8184, 7712)	1
#   (8217, 7712)	1
#   (8418, 7712)	1
#   (8575, 7712)	1
#   (9443, 7712)	1
#   (9908, 7712)	1
#   (9975, 7712)	1
#   (10174, 7712)	1
#   (10263, 7712)	1
#   (10321, 7712)	1
#   (10939, 7712)	1
#   (11032, 7712)	1
#   (12208, 7712)	1
#   (12625, 7712)	1
#   (12646, 7712)	1
#   (13007, 7712)	1
#   (13401, 7712)	1

# %%
gene_array = df_counts_sparse_gene_sel.index.values
print ( '\n\n  gene_array.shape:  ' ,  gene_array.shape )
print ( '\n gene_array: ' , gene_array)
# Out:
#   gene_array.shape:   (14472,)
#
#  gene_array:  ['ENSMUSG00000052305' 'ENSMUSG00000069919' 'ENSMUSG00000073940' ...
#  'ENSMUSG00000104861' 'ENSMUSG00000041144' 'ENSMUSG00000000154']

# %%
cell_array = df_counts_sparse_gene_sel.columns.values
print ( '\n\n  cell_array.shape:  ' ,  cell_array.shape )
print ( '\n cell_array: ' , cell_array)
# Out:
#   cell_array.shape:   (7713,)
#
#  cell_array:  ['AAACCCAAGCGAGTCA-1' 'AAACCCAAGGTCATTC-1' 'AAACCCACACTGTGTA-1' ...
#  'TTTGTTGGTGCTCTCT-1' 'TTTGTTGTCCCAGGAC-1' 'TTTGTTGTCTTCGACC-1']

# %%
f = open( nru_dict_dsn, 'wb' )    
pickle.dump( nru_dict, f)           
f.close()       

df_DE_stats.to_pickle ( DE_stats_dsn )

  
f = open( counts_scipy_csc_dsn, 'wb' )    
pickle.dump( scipy_csc_mat, f)           
f.close()       

f = open( gene_array_dsn, 'wb' )    
pickle.dump( gene_array, f)           
f.close()       

f = open( cell_array_dsn, 'wb' )    
pickle.dump( cell_array, f)           
f.close()
